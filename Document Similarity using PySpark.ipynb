# %%
# Common Packages

import os
import sys
import argparse
import warnings
from contextlib import suppress
import traceback
import logging

# Pyspark Packages
from pyspark.sql import SparkSession, Window
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql import functions as F, DataFrameReader
from pyspark.sql.types import (
    StringType,
    ArrayType,
    IntegerType,
    FloatType,
    StructType,
    StructField,
    BooleanType,
    MapType
)

from pyspark.ml.feature import Word2Vec, Tokenizer
from pyspark.ml.pipeline import Pipeline

# NLTK
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation

sw_indo = stopwords.words("indonesian") + list(punctuation)

# %%
def config():

    conf = SparkConf()
    # COMMON CONFIGURATION
    conf.set("spark.sql.caseSensitive", "true")
    conf.set("spark.debug.maxToStringFields", 200)
    conf.set("spark.sql.files.ignoreCorruptFiles", "true")
    conf.set('spark.sql.session.timeZone', 'Asia/Jakarta')

    return conf

# %%
def read_dataframe(fname):
    df = spark \
            .read \
            .option("quote", "\"") \
            .option("escape", "\"") \
            .csv("./data/kompas.csv", header=True, multiLine=True) \
            .withColumn("idx", F.monotonically_increasing_id()) \
            .withColumn("title", F.udf(lambda teks: teks.split("\n")[0], StringType())(F.col("teks")))
    
    return df

# %%
def text_preprocessing(text: str) -> str:

    text = text.lower()
    text = " ".join([word for word in word_tokenize(text) if word not in sw_indo])
    return text

def dataframe_cleaning(df):
    return (df \
                .withColumn("teks", 
                    F.udf(lambda text: text_preprocessing(text), StringType())(F.col("teks"))))

# %%
if __name__ == "__main__":

    try:
        
        conf = config()
        spark = SparkSession \
            .builder \
            .config(conf=conf) \
            .appName("Document Similarity") \
            .getOrCreate()
        sc = spark.sparkContext
        
        df = read_dataframe("./data/kompas.csv")
        df = dataframe_cleaning(df)
        
        tokenizer = Tokenizer(inputCol="teks", outputCol="word_tokenize")
        word2Vec = Word2Vec(
            vectorSize=200, 
            seed=42, 
            inputCol="word_tokenize", 
            outputCol="word_vector"
        )
#         train, test = df.randomSplit([0.8, 0.2], seed=42)
        model = Pipeline(stages=[tokenizer, word2Vec])
        model = model.fit(df)
        df = model.transform(df).drop("word_tokenize")
#         test = model.transform(test)
#         df = test.join(train, how="cross")
#         df.show(1, vertical=True)
#         spark.stop()

    except Exception as e:

        logging.error(traceback.format_exc())
        raise e

# %%
from umap import UMAP
import numpy as np
import pandas as pd
import plotly.express as px

# %%
vec = df.rdd.map(lambda x: x["word_vector"].values).collect()
title = df.rdd.map(lambda x: x["title"]).collect()

# %%
X = UMAP().fit_transform(vec)

# %%
df_plot = pd.DataFrame(X, columns=["umap1", "umap2"])
df_plot["text"] = title

# %%
fig = px.scatter(df_plot, x="umap1", y="umap2", hover_name="text")
fig.update_traces(textposition='top center')
fig.update_layout(
    height=800,
    title_text='Reduced Word2Vec Visualization'
)
fig.show()
# Out:
# <div>
#
#
#             <div id="da98a316-e5ec-4dce-bd24-e1e91d3ca013" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da98a316-e5ec-4dce-bd24-e1e91d3ca013")) {
#                     Plotly.newPlot(
#                         'da98a316-e5ec-4dce-bd24-e1e91d3ca013',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>umap1=%{x}<br>umap2=%{y}", "hovertext": ["Ginandjar Tetap Ditahan. Jaksa Agung Dilaporkan ke Polri", "Jakarta Dikangkangi Para Preman", "Penyimpangan di Setpres Seolah Terjadi Sekarang", "Dibayarkan, Rapel Kenaikan Gaji Pegawai Pos", "Stop Kekerasan, Elite agar Duduk Bersama", "Kapal Memuat Pasir Timah Kandas", "Orang-orang Bersayap Angin", "Tempat Tahanan Estrada Akan Dipindahkan", "CAR 20 Bank di Bawah 8 Persen", "Kebakaran di Rutan Imigrasi", "Tiga Anggota Brimob Dimakamkan", "Sekali Lagi, Goyang Ricky Martin...", "Pemerintah Diminta Hindari Kegagalan dengan IMF", "Mencari Mobil Hilang, Perlu Surat Kuasa", "Sri Mulyani: Perlu Melobi Negara Kreditor", "Semilyar buat yang Bisa Membuktikan", "Polisi Tangkap Pembawa Dua Pistol Tanpa Izin", "Presiden: Memorandum II Tak Perlu", "Bangsa Indonesia Butuh Platform Bersama", "Salah Gunakan DO BBM, Izin Keagenan Dicabut", "RUU Otonomi Khusus Aceh Gagasan Paling Moderat", "GAM: RI Ingkari Kesepakatan", "Jepang Restrukturisasi Utang Dollar Indonesia", "Kecuali Anggota, Dilarang Masuk", "Bambang Tri dan Indra Rukmana Ingin Lepas Sahamnya di Bimantara", "GM Utut Adianto Terus Melejit ke Babak II", "Prokasih, Belasan Tahun Percuma", "\"Kuwate\" Sambel, biar Tidak \"Kejungkel\"...", "Solar, Pagi Ada, Sore Habis", "Jaminan Kapolri, Jakarta Aman", "Ekonomi Nyatakan \"Vote of No Confidence\"", "Defisit Anggaran Bisa Meningkat", "Aksi Pembakaran Memasuki Kota Pangkalan Bun", "Amien Rais Bersedia Dialog", "Hentikan Segala Bentuk Kekerasan", "Persaudaraan Muslim Jangan Sampai Retak", "Persma Manado Jangan Sampai Degradasi", "Bank Dunia Menunda Pinjaman", "Bayern Lengkapi Balas Dendamnya", "Perlu Agenda Bersama Selesaikan Masalah Bangsa", "Milosevic Serahkan Diri", "Pertimbangkanlah Keselamatan Bangsa", "Pesawat Misionaris Ditembak", "Terserang Flu, Wapres Tak Hadiri Sidang Kabinet", "Lima Langkah Sulit Direalisasikan", "Leeds Terobos Empat Besar", "Sinyal Mengkhawatirkan Kebijakan Fiskal", "Pertemuan Empat Tokoh Harus Seiring Memorandum", "Polisi Bersihkan Bandung dari Kekerasan", "Pertama Kali, Ralf Schumacher Juara", "Empat Hari Listrik Padam di Bogor Timur", "DPR Janji Segera Loloskan RUU Otonomi Khusus Aceh", "Defisit APBN 2001 Sudah Rp 6,1 Trilyun", "Polisi dan Perampok Baku Tembak di Tebet", "BBM Industri Naik 50-100 Persen", "Mutu Hidup Masyarakat Turun", "Menkeu: Kondisi Anggaran Negara Kritis", "Kesepakatan RI-IMF Kemungkinan Besar Tak Tercapai", "Didemo Ribuan Warga, Indorayon Batal Beroperasi", "Purnomo Mengakui Pengiriman Solar Terlambat", "Gagal Jarah Hutan, Serang Petugas", "Bayarnya Pakai Rupiah, \"Ngukur\"-nya Dollar", "Gempa Kembali Guncang Bengkulu", "Pertemuan Empat Tokoh Tidak Perlu Agenda", "Ketika Minyak Tanah Tidak Lagi Menjanjikan", "KH Hasyim Muzadi: Tak Ada Instruksi untuk Jihad", "Puluhan Ribu Warga NU ke Jakarta", "\"Mobnas\" Buatan Petani", "Nelayan Jakarta, Anak Tiri Ibu Kota", "Kenangan Manis The Supremes", "Pemerintah Akan Tetap Bayar Gaji Perum PPD", "Misa Malam Paskah Khidmat", "Pemerintah Lakukan Pemetaan terhadap Perbankan", "Kelangkaan Solar Mulai Terasa", "Cina Lepaskan Kru Pesawat Pengintai AS", "Rumah Terbakar, Ayah dan Dua Anak Tewas", "Kejaksaan Periksa Sepuluh Karyawan PT DI", "Indonesiaku: Ayo Kerja", "Pemerintah Ajak IMF Tak Ulangi Kesalahan Masa Lalu", "Satgas GPK dan AMK Siap Bantu Amankan Jakarta", "DIY dan Jambi Kerja Sama Industri Kerajinan", "Jika Sistem \"Spot\" Diberlakukan, Penjualan LNG Nasional Cenderung Turun", "Ginandjar Ditahan", "IMF Ingin Dana Perimbangan APBN Dikaji Ulang", "SLB Pembina Sulsel Kehilangan Murid", "Kelangkaan Solar Semakin Meluas", "Kodam Trikora Bertekad Mengejar OPM", "22 Warga Irak Kabur dari Karantina Imigrasi", "Mengapa Belanda Pilih Euthanasia?", "MU Catat \"Hat-trick\" Juara", "IMF dan Krisis Ekonomi: Apa Hubungannya?", "Rehabilitasi RS Tentara Siap Diresmikan", "Istigotsah Tetap Dilaksanakan 29 April", "Mas Dwiy ...
